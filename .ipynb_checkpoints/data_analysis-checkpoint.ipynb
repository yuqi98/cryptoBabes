# %%
import pandas as pd
bitdata = pd.read_csv('/Users/yuqizhang/my-python-project/cryptoBabes/Bitfinex_BTCEUR_trades_2018_02_02.csv')
print(bitdata)
# Out:
#               id exchange  symbol           date        price    amount   sell
# 0      183601815       bf  btceur  1517529608000  7349.600000  0.004568  False
# 1      183601825       bf  btceur  1517529609000  7354.680450  0.010000   True
# 2      183601823       bf  btceur  1517529609000  7354.680450  0.004568   True
# 3      183601833       bf  btceur  1517529610000  7354.600000  0.102395  False
# 4      183601904       bf  btceur  1517529626000  7343.407500  0.086580  False
# 5      183601906       bf  btceur  1517529626000  7343.807250  0.204920  False
# 6      183602055       bf  btceur  1517529638000  7356.000000  0.300000  False
# 7      183602057       bf  btceur  1517529638000  7357.900000  0.088007  False
# 8      183602052       bf  btceur  1517529638000  7355.800000  0.100000  False
# 9      183602064       bf  btceur  1517529639000  7343.167650  0.088007  False
# 10     183602333       bf  btceur  1517529675000  7352.281950  0.002000   True
# ...

# %%
import matplotlib.pyplot as plt
import dateandtime

# %%
def change_date(row):
    data = row['date']
    return pd.Series({'date':dateandtime.convert_dates(data)})

new_date = bitdata.apply(change_date, axis = 1)


print(new_date)
# Out:
#                      date
# 0     2018-02-02 02:00:08
# 1     2018-02-02 02:00:09
# 2     2018-02-02 02:00:09
# 3     2018-02-02 02:00:10
# 4     2018-02-02 02:00:26
# 5     2018-02-02 02:00:26
# 6     2018-02-02 02:00:38
# 7     2018-02-02 02:00:38
# 8     2018-02-02 02:00:38
# 9     2018-02-02 02:00:39
# 10    2018-02-02 02:01:15
# 11    2018-02-02 02:01:55
# 12    2018-02-02 02:01:55
# 13    2018-02-02 02:01:55
# 14    2018-02-02 02:01:55
# 15    2018-02-02 02:01:55
# 16    2018-02-02 02:01:55
# 17    2018-02-02 02:02:00
# 18    2018-02-02 02:02:07
# 19    2018-02-02 02:02:07
# 20    2018-02-02 02:02:07
# 21    2018-02-02 02:02:07
# 22    2018-02-02 02:02:07
# 23    2018-02-02 02:02:11
# 24    2018-02-02 02:02:19
# 25    2018-02-02 02:02:21
# 26    2018-02-02 02:02:36
# 27    2018-02-02 02:04:31
# 28    2018-02-02 02:05:02
# 29    2018-02-02 02:05:15
# ...                   ...
# 15685 2018-02-03 01:54:35
# 15686 2018-02-03 01:54:35
# 15687 2018-02-03 01:54:35
# ...

# %%
type(new_date)
# Out:
# pandas.core.frame.DataFrame

# %%
new_bitdata = bitdata.drop(columns=['exchange','symbol','date'])
new_bitdata.join(new_date)
# Out:
#               id        price    amount   sell                date
# 0      183601815  7349.600000  0.004568  False 2018-02-02 02:00:08
# 1      183601825  7354.680450  0.010000   True 2018-02-02 02:00:09
# 2      183601823  7354.680450  0.004568   True 2018-02-02 02:00:09
# 3      183601833  7354.600000  0.102395  False 2018-02-02 02:00:10
# 4      183601904  7343.407500  0.086580  False 2018-02-02 02:00:26
# 5      183601906  7343.807250  0.204920  False 2018-02-02 02:00:26
# 6      183602055  7356.000000  0.300000  False 2018-02-02 02:00:38
# 7      183602057  7357.900000  0.088007  False 2018-02-02 02:00:38
# 8      183602052  7355.800000  0.100000  False 2018-02-02 02:00:38
# 9      183602064  7343.167650  0.088007  False 2018-02-02 02:00:39
# 10     183602333  7352.281950  0.002000   True 2018-02-02 02:01:15
# 11     183602610  7351.320200  0.300000   True 2018-02-02 02:01:55
# 12     183602612  7351.320200  0.300000   True 2018-02-02 02:01:55
# ...

# %%
new_bitdata.to_csv('datawithnewdate.csv')
