# %%
import pandas as pd

import dateandtime

import new_process

# %%
bitdata = pd.read_csv('tIOSBTC.csv')

new_process.preprocess(bitdata)

bitdata = pd.read_csv('tIOSBTC.csv')
# Out:
#              ID         MTS    AMOUNT        PRICE             time hours  \
# 0     264428531  2018-07-02 -0.200000  6622.000000  18:53:00.219000    18
# 1     264428520  2018-07-02 -0.290001  6622.000000  18:52:54.735000    18
# 2     264428512  2018-07-02  0.118359  6622.100000  18:52:50.966000    18
# 3     264428511  2018-07-02  0.432000  6622.100000  18:52:50.963000    18
# 4     264428510  2018-07-02  0.302020  6622.100000  18:52:50.961000    18
# 5     264428509  2018-07-02  0.147621  6622.100000  18:52:50.957000    18
# 6     264428506  2018-07-02  0.002379  6622.100000  18:52:49.359000    18
# 7     264428505  2018-07-02  0.010000  6622.100000  18:52:49.357000    18
# 8     264428495  2018-07-02 -0.133438  6622.000000  18:52:46.557000    18
# 9     264428494  2018-07-02 -0.086557  6622.000000  18:52:46.555000    18
# 10    264428482  2018-07-02 -0.251479  6622.000000  18:52:43.983000    18
# 11    264428453  2018-07-02 -0.121000  6622.000000  18:52:36.254000    18
# ...
