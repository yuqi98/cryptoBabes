# %%
import matplotlib.pyplot as plt
import datetime
import pandas as pd
import os
import numpy as np
import math
from IPython.display import Image

# %matplotlib inline
plt.style.use('seaborn-whitegrid')
fig = plt.figure()

# %%
def simple_plot():
    df = pd.read_csv('/Users/SurabhiGupta/Desktop/Github/cryptoBabes/four_feature_hour.csv')
    plt.plot(df['hours'], df['average'], linestyle='dashed')
    
    df2 = pd.read_csv('/Users/SurabhiGupta/Desktop/Github/cryptoBabes/preprocessed1.csv')
    
    i = 0

    df2.groupby(['sell']).plot(x='time', y='price')

    for group_name, group in df2.groupby(['sell']):
        print(group_name, '\n')
        print(group.head(), '\n\n\n')
        print('####################### Group ########################\n')
        i += 1

# %%
simple_plot()
# Out:
# False
#
#    Unnamed: 0         id       price    amount   sell        date      time  \
# 0           0  183601815  7349.60000  0.004568  False  2018-02-02  02:00:08
# 3           3  183601833  7354.60000  0.102395  False  2018-02-02  02:00:10
# 4           4  183601904  7343.40750  0.086580  False  2018-02-02  02:00:26
# 5           5  183601906  7343.80725  0.204920  False  2018-02-02  02:00:26
# 6           6  183602055  7356.00000  0.300000  False  2018-02-02  02:00:38
#
#    hours  minutes  seconds hour_minute
# 0      2        0        8       02:00
# 3      2        0       10       02:00
# 4      2        0       26       02:00
# 5      2        0       26       02:00
# 6      2        0       38       02:00
#
#
#
# ####################### Group ########################
#
# True
#
#     Unnamed: 0         id       price    amount  sell        date      time  \
# 1            1  183601825  7354.68045  0.010000  True  2018-02-02  02:00:09
# 2            2  183601823  7354.68045  0.004568  True  2018-02-02  02:00:09
# 10          10  183602333  7352.28195  0.002000  True  2018-02-02  02:01:15
# 11          11  183602610  7351.32020  0.300000  True  2018-02-02  02:01:55
# 12          12  183602612  7351.32020  0.300000  True  2018-02-02  02:01:55
#
#     hours  minutes  seconds hour_minute
# 1       2        0        9       02:00
# 2       2        0        9       02:00
# 10      2        1       15       02:01
# 11      2        1       55       02:01
# 12      2        1       55       02:01
#
#
#
# ####################### Group ########################
